# %%
import tarfile
import boto3
from pathlib import Path
import logging
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.workflow.pipeline import Pipeline
from sagemaker.workflow.steps import ProcessingStep, TrainingStep
from sagemaker.xgboost import XGBoost

# %%
import os
import boto3
from botocore.exceptions import ClientError, NoCredentialsError
from pathlib import Path
import logging

def upload_directory_to_s3(local_path, bucket, prefix):
    """Upload directory to S3 with comprehensive error handling"""
    # Configure logging
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger(__name__)
    
    s3_client = boto3.client('s3')
    local_path = Path(local_path)
    uploaded_count = 0
    
    try:
        # VERIFY PATH EXISTS
        if not local_path.exists():
            # Try case-insensitive search
            parent = local_path.parent
            possible_dirs = [d for d in parent.iterdir() 
                            if d.is_dir() and d.name.lower() == local_path.name.lower()]
            
            if not possible_dirs:
                raise FileNotFoundError(f"Local path {local_path} does not exist")
            
            # Use first matching directory
            local_path = possible_dirs[0]
            logger.warning(f"Using case-corrected path: {local_path}")

        # Walk through directory
        for root, _, files in os.walk(local_path):
            for file in files:
                file_path = Path(root) / file
                relative_path = file_path.relative_to(local_path)
                s3_key = f"{prefix}/{relative_path}"
                
                try:
                    s3_client.upload_file(
                        Filename=str(file_path),
                        Bucket=bucket,
                        Key=str(s3_key)
                    )
                    uploaded_count += 1
                    logger.info(f"Uploaded: {file_path} → s3://{bucket}/{s3_key}")
                except (ClientError, NoCredentialsError) as e:
                    logger.error(f"Failed to upload {file_path}: {str(e)}")
                    continue
        
        logger.info(f"✅ Successfully uploaded {uploaded_count} files to s3://{bucket}/{prefix}")
        return True
        
    except Exception as e:
        logger.exception(f"Critical upload error: {str(e)}")
        return False

# CORRECTED USAGE
BUCKET = "sentiment-analysis-workflow"
PREFIX = "imdb-sentiment-analysis/raw_data"
LOCAL_PATH = "../data/aclImdb"  # Note the capital "I"

# Verify path before uploading
print("Current directory:", os.getcwd())
# print("Data directory exists:", Path("data").exists())
print("aclImdb exists:", Path("../data/aclImdb").exists())
# print("Contents of data directory:", os.listdir("data"))

if upload_directory_to_s3(LOCAL_PATH, BUCKET, PREFIX):
    print("Upload successful!")
else:
    print("Upload failed. Check logs for details.")
# Out:
# INFO:__main__:Uploaded: ../data/aclImdb/imdb.vocab → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/imdb.vocab
# Current directory: /home/ec2-user/SageMaker/e2e-IMDb-sentiment-analysis-sagemaker-workflow
# aclImdb exists: True
# INFO:__main__:Uploaded: ../data/aclImdb/imdbEr.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/imdbEr.txt
# INFO:__main__:Uploaded: ../data/aclImdb/README → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/README
# INFO:__main__:Uploaded: ../data/aclImdb/test/urls_pos.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/urls_pos.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/urls_neg.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/urls_neg.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/labeledBow.feat → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/labeledBow.feat
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8557_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8557_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/922_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/922_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5249_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5249_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1261_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1261_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5964_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5964_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4379_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4379_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4519_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4519_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6576_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6576_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9147_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9147_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10316_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10316_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5126_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5126_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10035_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10035_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2455_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2455_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10026_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10026_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7346_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7346_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6275_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6275_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9520_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9520_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11743_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11743_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2185_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2185_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9577_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9577_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5859_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5859_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9553_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9553_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5987_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5987_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5340_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5340_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5496_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5496_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10752_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10752_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11715_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11715_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1557_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1557_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6233_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6233_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9017_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9017_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8911_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8911_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6329_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6329_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/764_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/764_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6788_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6788_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5163_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5163_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3851_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3851_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2622_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2622_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11503_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11503_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9389_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9389_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5326_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5326_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10211_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10211_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11363_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11363_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8897_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8897_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7227_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7227_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6371_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6371_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1369_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1369_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10713_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10713_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12431_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12431_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5886_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5886_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3095_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3095_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/736_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/736_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8001_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8001_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9134_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9134_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8206_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8206_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11393_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11393_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12078_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12078_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5213_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5213_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9222_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9222_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9748_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9748_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8827_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8827_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2981_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2981_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10513_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10513_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5115_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5115_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11374_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11374_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7692_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7692_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9333_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9333_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/89_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/89_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5793_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5793_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12335_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12335_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9002_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9002_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/608_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/608_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11315_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11315_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/35_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/35_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/755_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/755_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3003_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3003_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1217_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1217_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9450_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9450_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9673_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9673_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4604_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4604_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3156_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3156_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9677_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9677_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10630_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10630_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8394_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8394_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1092_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1092_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3972_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3972_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8510_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8510_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5855_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5855_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5221_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5221_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5514_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5514_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7724_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7724_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9331_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9331_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6324_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6324_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11665_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11665_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5898_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5898_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8608_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8608_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2600_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2600_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10252_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10252_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2380_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2380_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/950_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/950_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3453_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3453_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9449_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9449_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10337_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10337_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7926_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7926_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5418_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5418_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/206_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/206_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7537_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7537_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11115_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11115_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4998_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4998_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6277_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6277_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8635_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8635_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10424_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10424_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9552_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9552_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9169_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9169_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11773_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11773_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/626_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/626_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6262_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6262_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12294_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12294_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6397_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6397_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11098_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11098_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4211_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4211_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6870_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6870_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8929_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8929_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3285_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3285_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11646_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11646_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3476_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3476_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12492_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12492_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7041_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7041_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1699_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1699_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11275_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11275_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2007_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2007_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4563_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4563_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/881_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/881_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9462_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9462_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9996_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9996_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7125_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7125_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8819_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8819_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/411_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/411_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9915_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9915_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11127_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11127_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10871_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10871_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7998_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7998_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10644_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10644_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10814_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10814_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/965_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/965_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11813_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11813_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3211_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3211_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6367_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6367_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11922_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11922_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5501_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5501_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4430_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4430_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7821_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7821_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/725_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/725_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3827_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3827_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5621_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5621_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2861_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2861_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11159_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11159_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6309_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6309_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4247_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4247_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3915_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3915_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6531_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6531_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1093_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1093_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11448_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11448_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6746_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6746_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2376_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2376_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2948_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2948_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8254_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8254_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1692_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1692_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9566_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9566_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3319_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3319_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9641_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9641_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10465_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10465_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1969_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1969_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2850_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2850_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5391_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5391_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9195_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9195_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2363_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2363_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12220_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12220_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8478_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8478_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2732_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2732_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4204_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4204_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3839_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3839_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5288_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5288_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6920_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6920_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9092_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9092_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11335_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11335_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7759_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7759_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9135_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9135_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11796_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11796_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5425_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5425_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/776_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/776_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9754_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9754_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9268_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9268_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5578_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5578_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6516_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6516_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2662_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2662_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/341_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/341_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7446_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7446_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7618_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7618_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5198_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5198_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1247_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1247_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6051_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6051_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4303_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4303_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2642_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2642_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7786_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7786_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6318_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6318_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12296_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12296_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11065_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11065_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2977_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2977_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2062_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2062_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12114_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12114_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/772_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/772_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5252_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5252_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9529_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9529_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2368_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2368_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10820_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10820_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/796_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/796_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2913_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2913_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6442_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6442_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9068_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9068_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10304_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10304_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1245_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1245_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1332_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1332_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11706_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11706_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8756_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8756_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2738_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2738_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6021_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6021_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9228_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9228_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9561_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9561_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6966_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6966_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/735_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/735_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11971_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11971_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4922_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4922_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3263_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3263_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4736_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4736_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/885_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/885_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4362_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4362_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1761_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1761_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9794_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9794_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12074_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12074_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9319_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9319_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8921_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8921_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4040_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4040_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1705_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1705_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/960_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/960_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5617_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5617_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4617_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4617_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3442_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3442_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7990_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7990_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7329_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7329_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1348_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1348_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2199_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2199_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7324_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7324_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1419_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1419_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11015_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11015_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10689_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10689_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3590_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3590_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4179_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4179_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3163_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3163_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12382_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12382_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10714_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10714_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6062_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6062_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9089_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9089_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4908_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4908_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3549_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3549_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11300_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11300_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/896_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/896_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2906_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2906_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3850_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3850_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7858_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7858_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5176_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5176_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1451_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1451_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/610_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/610_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5258_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5258_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11326_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11326_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4754_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4754_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10157_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10157_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3882_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3882_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10839_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10839_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9585_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9585_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5263_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5263_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5691_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5691_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8552_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8552_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6236_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6236_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8595_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8595_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/355_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/355_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1707_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1707_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12064_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12064_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6517_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6517_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2668_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2668_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7576_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7576_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2802_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2802_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10279_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10279_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9769_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9769_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/602_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/602_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/645_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/645_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10065_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10065_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4350_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4350_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1421_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1421_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8821_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8821_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8809_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8809_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3076_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3076_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11800_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11800_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1686_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1686_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5125_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5125_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8389_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8389_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7689_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7689_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9230_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9230_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/585_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/585_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/224_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/224_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4031_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4031_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11575_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11575_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11206_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11206_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4371_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4371_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12284_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12284_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10519_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10519_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10298_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10298_1.txt
# ...
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10412_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10412_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10818_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10818_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3144_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3144_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1777_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1777_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9353_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9353_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4772_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4772_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6055_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6055_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9982_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9982_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4191_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4191_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4254_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4254_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9816_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9816_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6103_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6103_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8540_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8540_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2304_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2304_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4690_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4690_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2258_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2258_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10141_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10141_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6232_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6232_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6399_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6399_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9248_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9248_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6194_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6194_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4885_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4885_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8081_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8081_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9716_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9716_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6445_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6445_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5348_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5348_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4255_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4255_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6922_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6922_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2465_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2465_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9203_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9203_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3018_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3018_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8698_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8698_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11449_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11449_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6988_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6988_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2499_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2499_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8630_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8630_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10878_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10878_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1573_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1573_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9611_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9611_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3395_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3395_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5642_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5642_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4409_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4409_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7159_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7159_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4258_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4258_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10772_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10772_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9321_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9321_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/554_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/554_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3074_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3074_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8458_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8458_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/479_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/479_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/14_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/14_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/120_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/120_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8224_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8224_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1736_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1736_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1827_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1827_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4603_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4603_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5071_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5071_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2905_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2905_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11249_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11249_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11999_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11999_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4989_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4989_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11973_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11973_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7812_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7812_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5243_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5243_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1429_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1429_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10064_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10064_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9411_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9411_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2233_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2233_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3035_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3035_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/695_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/695_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2769_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2769_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12201_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12201_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9581_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9581_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10548_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10548_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/7298_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/7298_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6489_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6489_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11179_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11179_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6002_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6002_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/856_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/856_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1198_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1198_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1364_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1364_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/701_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/701_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4804_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4804_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2009_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2009_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6818_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6818_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5410_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5410_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/9616_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/9616_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10787_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10787_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10339_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10339_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/8419_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/8419_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6430_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6430_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/6725_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/6725_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/4682_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/4682_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/11714_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/11714_1.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10488_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10488_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5321_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5321_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/1040_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/1040_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5486_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5486_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2778_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2778_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/10267_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/10267_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3698_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3698_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12424_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12424_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/5011_4.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/5011_4.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/3301_2.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/3301_2.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/2472_3.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/2472_3.txt
# INFO:__main__:Uploaded: ../data/aclImdb/test/neg/12289_1.txt → s3://sentiment-analysis-workflow/imdb-sentiment-analysis/raw_data/test/neg/12289_1.txt

# %%
def upload_directory_to_s3(local_path, bucket, prefix):
    """Upload directory to S3 with comprehensive error handling"""
    # Configure logging
    logging.basicConfig(level=logging.INFO)
    logger = logging.getLogger(__name__)
    
    s3_client = boto3.client('s3')
    local_path = Path(local_path)
    uploaded_count = 0
    
    try:
        # Verify local path exists
        if not local_path.exists():
            raise FileNotFoundError(f"Local path {local_path} does not exist")
        
        # Walk through directory
        for root, _, files in os.walk(local_path):
            for file in files:
                file_path = Path(root) / file
                relative_path = file_path.relative_to(local_path)
                s3_key = f"{prefix}/{relative_path}"
                
                try:
                    s3_client.upload_file(
                        Filename=str(file_path),
                        Bucket=bucket,
                        Key=str(s3_key))
                    uploaded_count += 1
                    logger.info(f"Uploaded: {file_path} → s3://{bucket}/{s3_key}")
                except (ClientError, NoCredentialsError) as e:
                    logger.error(f"Failed to upload {file_path}: {str(e)}")
                    continue
        
        logger.info(f"✅ Successfully uploaded {uploaded_count} files to s3://{bucket}/{prefix}")
        return True
        
    except Exception as e:
        logger.exception(f"Critical upload error: {str(e)}")
        return False

# Usage example:
BUCKET = "sentiment-analysis-workflow"
PREFIX = "imdb-sentiment-analysis/raw_data"
LOCAL_PATH = "data/aclImdb"

if upload_directory_to_s3(LOCAL_PATH, BUCKET, PREFIX):
    print("Upload successful!")
else:
    print("Upload failed. Check logs for details.")
# Out:
# ERROR:__main__:Critical upload error: Local path data/aclImdb does not exist
# Traceback (most recent call last):
#   File "/tmp/ipykernel_6338/1346181515.py", line 14, in upload_directory_to_s3
#     raise FileNotFoundError(f"Local path {local_path} does not exist")
# FileNotFoundError: Local path data/aclImdb does not exist
# Upload failed. Check logs for details.

# %%
def upload_to_s3(local_path, s3_uri):
    """Upload local file/directory to S3"""
    session = boto3.Session()
    s3 = session.resource('s3')
    bucket, key_prefix = s3_uri.replace("s3://", "").split("/", 1)
    
    if Path(local_path).is_dir():
        for file in Path(local_path).rglob('*'):
            if file.is_file():
                s3_key = f"{key_prefix}/{file.relative_to(local_path)}"
                s3.Bucket(bucket).upload_file(str(file), s3_key)
    else:
        s3.Bucket(bucket).upload_file(local_path, f"{key_prefix}/{Path(local_path).name}")

def get_imdb_data_s3(config):
    """Ensure IMDb data is in S3, return S3 URI"""
    s3_data_uri = f"s3://{config['bucket']}/{config['prefix']}/raw_data"
    local_dir = Path('data/aclImdb')
    
    # Download and extract data if missing locally
    if not local_dir.exists():
        os.makedirs('data', exist_ok=True)
        tar_path = 'data/aclImdb_v1.tar.gz'
        if not Path(tar_path).exists():
            os.system(f'wget -P data/ https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz')
        with tarfile.open(tar_path) as tar:
            tar.extractall(path='data/')
    
    # Upload to S3
    upload_to_s3(str(local_dir), s3_data_uri)
    return f"{s3_data_uri}/aclImdb"

# %%
def create_processing_step(role, s3_data_uri, config):
    """Create processing job with S3 input"""
    # Upload processing script to S3
    s3_script_uri = f"s3://{config['bucket']}/{config['prefix']}/scripts/processing_job.py"
    upload_to_s3('scripts/processing_job.py', s3_script_uri)
    
    sklearn_processor = SKLearnProcessor(
        framework_version='1.2-1',
        role=role,
        instance_type='ml.m5.large',
        instance_count=1,
        base_job_name='imdb-processing'
    )
    
    return ProcessingStep(
        name='IMDBDataProcessing',
        processor=sklearn_processor,
        inputs=[
            ProcessingInput(
                source=s3_data_uri,  # S3 instead of local
                destination='/opt/ml/processing/input/data'
            )
        ],
        outputs=[
            ProcessingOutput(output_name='train', source='/opt/ml/processing/output/train'),
            ProcessingOutput(output_name='validation', source='/opt/ml/processing/output/validation'),
            ProcessingOutput(output_name='test', source='/opt/ml/processing/output/test'),
            ProcessingOutput(output_name='vectorizer', source='/opt/ml/processing/output/vectorizer')
        ],
        code=s3_script_uri  # Use S3 path for script
    )

# %%
def main():
    # Initialize SageMaker
    session = sagemaker.Session()
    role = get_execution_role()
    region = session.boto_region_name
    bucket = session.default_bucket()  # Use default bucket
    prefix = 'imdb-sentiment-analysis'
    
    config = {
        "session": session,
        "role": role,
        "region": region,
        "bucket": bucket,
        "prefix": prefix
    }
    
    # 1. Upload data to S3
    s3_data_uri = get_imdb_data_s3(config)
    
    # 2. Create pipeline steps
    # processing_step = create_processing_step(role, s3_data_uri, config)
    # train_s3 = f"{processing_step.properties.ProcessingOutputConfig.Outputs['train'].S3Output.S3Uri}"
    # val_s3 = f"{processing_step.properties.ProcessingOutputConfig.Outputs['validation'].S3Output.S3Uri}"
    
    # # 3. Upload training script to S3
    # s3_train_script = f"s3://{bucket}/{prefix}/scripts/train.py"
    # upload_to_s3('scripts/train.py', s3_train_script)
    
    # # 4. Training step (using S3 script)
    # container = sagemaker.image_uris.retrieve('xgboost', region, '1.7-1')
    # xgb_estimator = XGBoost(
    #     entry_point=s3_train_script,  # S3 script path
    #     image_uri=container,
    #     role=role,
    #     instance_count=1,
    #     instance_type='ml.m5.2xlarge',
    #     framework_version='1.7-1',
    #     output_path=f's3://{bucket}/{prefix}/models'
    # )
    
    # training_step = TrainingStep(
    #     name='IMDBModelTraining',
    #     estimator=xgb_estimator,
    #     inputs={
    #         'train': TrainingInput(train_s3, content_type='text/csv'),
    #         'validation': TrainingInput(val_s3, content_type='text/csv')
    #     }
    # )

# %%
# 5. Create and run pipeline
    pipeline = Pipeline(
        name='IMDBSentimentPipeline',
        steps=[processing_step, training_step],
        sagemaker_session=session
    )
    
    pipeline.upsert(role_arn=role)
    execution = pipeline.start()
    execution.wait()
    
    # ... (deployment code remains the same)

if __name__ == "__main__":
    main()
